# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoBR23/jupyter/blob/main/populacao2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
url = 'https://raw.githubusercontent.com/GustavoBR23/jupyter/main/world_population.csv'
df1 = pd.read_csv(url)
df = pd.read_csv(url)

# %%
population = df.groupby(['Continent','Country/Territory','CCA3'])[['2022 Population',
                                                                   '2020 Population',
                                                                   '2015 Population',
                                                                   '2010 Population',
                                                                   '2000 Population',
                                                                   '1990 Population',
                                                                   '1980 Population',
                                                                   '1970 Population']
                                                                 ].value_counts().reset_index()
pop_growth = population.melt(id_vars = ['Continent','Country/Territory','CCA3'],
                             value_vars = ['2022 Population',
                                           '2020 Population',
                                           '2015 Population',
                                           '2010 Population',
                                           '2000 Population',
                                           '1990 Population',
                                           '1980 Population',
                                           '1970 Population'],
var_name = 'Years')
pop_growth.rename(columns = {'value':'Population'}, inplace = True)
pop_growth['Year'] = pop_growth['Years'].str.split(' ').str[0]
pop_gr = pop_growth.sort_values(by ='Year', ascending = True)
fig = px.choropleth(pop_gr,
                    locations="CCA3",
                    color="Population",
                    hover_name = 'Country/Territory',
                    animation_frame="Year",
                    animation_group="CCA3")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-feb875eb778b> in <cell line: 1>()
# ----> 1 population = df.groupby(['Continent','Country/Territory','CCA3'])[['2022 Population',
#       2                                                                    '2020 Population',
#       3                                                                    '2015 Population',
#       4                                                                    '2010 Population',
#       5                                                                    '2000 Population',
#
# NameError: name 'df' is not defined

# %%
fig = px.choropleth(df,
                    locations='CCA3',
                    color='Area (km²)',
                    hover_name='Country/Territory',
                    title='Area De Cada País')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
con_pop = pop_gr.groupby(['Continent','Year']).Population.sum().reset_index()
fig = px.bar(con_pop, x="Continent",
             y="Population",
             color="Continent",
             animation_frame="Year",
             animation_group="Continent",
             range_y=[0,5000000000])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
